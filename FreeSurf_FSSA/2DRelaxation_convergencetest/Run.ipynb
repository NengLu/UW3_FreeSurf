# %%
import matplotlib.pyplot as plt
import numpy as np

import os
import glob

from matplotlib import rc

# Set the global font to be DejaVu Sans, size 10 (or any other sans-serif font of your choice!)
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica'],'size':10})

# Set the font used for MathJax
rc('mathtext',**{'default':'regular'})
rc('figure',**{'figsize':(8,6)})

# rc('text',**{'usetex':True})

# plt.rcParams['text.usetex'] = True # TeX rendering

# %%
def run_2DRelaxation(timeratio):
    os.system(f'python3 Ex_2DRelaxation_FreeSurf.py {timeratio}')

# %%
test_timeratio = [0, 1, 2, 3, 4]
for timeratio in test_timeratio:
    run_2DRelaxation(timeratio)
# Out:
# [0, 1, 2, 3, 4]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 print(test_timeratio)
#       9 for timeratio in test_timeratio:
# ---> 10     run_2DRelaxation(timeratio)
#
# Cell In[2], line 2, in run_2DRelaxation(timeratio)
#       1 def run_2DRelaxation(timeratio):
# ----> 2     os.system(f'python3 Ex_2DRelaxation_FreeSurf.py {timeratio}')
#
# NameError: name 'os' is not defined
# op_2DRelaxation_FreeSurf_yres80_dt0.18ka_Tmax47.2ka/
# Step:     0 Model Time: 0.0 year dt: 0.0 year (2024-05-11 01:36:22)
#   0 SNES Function norm 2487.65
#   Nonlinear  solve did not converge due to DIVERGED_MAX_IT iterations 0
#   0 SNES Function norm 2487.65
#   1 SNES Function norm 0.0206578
#   2 SNES Function norm 3.92527e-05
#   3 SNES Function norm 2.53621e-07
#   Nonlinear  solve converged due to CONVERGED_FNORM_ABS iterations 3
#
# Save data:
#
# ...

# %%
run_2DRelaxation(4)
# Out:
# op_2DRelaxation_FreeSurf_yres80_dt0.05ka_Tmax47.2ka/
# Step:     0 Model Time: 0.0 year dt: 0.0 year (2024-05-11 03:12:30)
#   0 SNES Function norm 2487.65
#   Nonlinear  solve did not converge due to DIVERGED_MAX_IT iterations 0
#   0 SNES Function norm 2487.65
#   1 SNES Function norm 0.0206578
#   2 SNES Function norm 3.92527e-05
#   3 SNES Function norm 2.53621e-07
#   Nonlinear  solve converged due to CONVERGED_FNORM_ABS iterations 3
#
# Save data:
#
# repopulate start:
#
# repopulate end:
# Step:     1 Model Time: 46.1 year dt: 46.1 year (2024-05-11 03:12:44)
#   0 SNES Function norm 2487.65
#   Nonlinear  solve did not converge due to DIVERGED_MAX_IT iterations 0
#   0 SNES Function norm 0.0104113
#   1 SNES Function norm 0.000186776
#   2 SNES Function norm 3.09214e-05
#   3 SNES Function norm 8.163e-11
#   Nonlinear  solve converged due to CONVERGED_FNORM_ABS iterations 3
#
# repopulate start:
#
# repopulate end:
# ...

# %%
def run_2DRelaxation(timeratio):
    os.system(f'python3 Ex_2DRelaxation_FreeSurf_FSSA0.5.py {timeratio}')

test_timeratio = [4,2,1,0,-1,-2]

for timeratio in test_timeratio:
    run_2DRelaxation(timeratio)
# Out:
# op_2DRelaxation_FreeSurf_FSSA0.5_yres80_dt0.74ka_Tmax47.2ka/
# Step:     0 Model Time: 0.0 year dt: 0.0 year (2024-05-11 06:10:34)
#   0 SNES Function norm 2487.65
#   Nonlinear  solve did not converge due to DIVERGED_MAX_IT iterations 0
#   0 SNES Function norm 2487.65
#   1 SNES Function norm 80.6795
#   2 SNES Function norm 32.2874
#   3 SNES Function norm 1.52757
#   4 SNES Function norm 0.0125327
#   5 SNES Function norm 0.000680352
#   6 SNES Function norm 1.85084e-06
#   Nonlinear  solve converged due to CONVERGED_FNORM_ABS iterations 6
#
# Save data:
#
# repopulate start:
#
# repopulate end:
# Step:     1 Model Time: 737.4 year dt: 737.4 year (2024-05-11 06:10:48)
#   0 SNES Function norm 2487.65
#   Nonlinear  solve did not converge due to DIVERGED_MAX_IT iterations 0
#   0 SNES Function norm 0.16156
#   1 SNES Function norm 0.0164343
#   2 SNES Function norm 8.76961e-05
#   3 SNES Function norm 4.75878e-06
#   4 SNES Function norm 3.216e-11
# ...

# %%
def run_2DRelaxation(timeratio):
    os.system(f'python3 Ex_2DRelaxation_FreeSurf_FSSA1.py {timeratio}')

test_timeratio = [4,2,1,0,-1,-2]

for timeratio in test_timeratio:
    run_2DRelaxation(timeratio)
# Out:
# op_2DRelaxation_FreeSurf_FSSA1_yres80_dt0.74ka_Tmax47.2ka/
# Step:     0 Model Time: 0.0 year dt: 0.0 year (2024-05-11 06:30:21)
#   0 SNES Function norm 2487.65
#   Nonlinear  solve did not converge due to DIVERGED_MAX_IT iterations 0
#   0 SNES Function norm 2487.65
#   1 SNES Function norm 109.642
#   2 SNES Function norm 0.260046
#   3 SNES Function norm 0.00143729
#   4 SNES Function norm 8.26116e-06
#   5 SNES Function norm 3.30507e-07
#   Nonlinear  solve converged due to CONVERGED_FNORM_ABS iterations 5
#
# Save data:
#
# repopulate start:
#
# repopulate end:
# Step:     1 Model Time: 737.4 year dt: 737.4 year (2024-05-11 06:30:35)
#   0 SNES Function norm 2487.65
#   Nonlinear  solve did not converge due to DIVERGED_MAX_IT iterations 0
#   0 SNES Function norm 0.156838
#   1 SNES Function norm 2.45529e-05
#   2 SNES Function norm 2.9518e-06
#   3 SNES Function norm 1.47618e-06
#   Nonlinear  solve converged due to CONVERGED_FNORM_ABS iterations 3
#
# repopulate start:
#
# ...
